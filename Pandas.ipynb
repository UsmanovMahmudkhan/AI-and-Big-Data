# %%
import pandas as pd
import numpy as np

# %%
pd.Series([1,2,4,5],index=['a','b','c','d'])
# Out:
# a    1
# b    2
# c    4
# d    5
# dtype: int64

# %%
arr=np.array([10,20,30,40,50])

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# From **Dictionary**

# %%
dic={'a':2,'b':4,'c':6}
pd.Series(dic)
# Out:
# a    2
# b    4
# c    6
# dtype: int64

# %%
pd.Series([sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %% [markdown]
# **How to access data by index**

# %%
SER=pd.Series([1,2,3,4],index=['india','usa','soutth korea','german'])

# %%
SER
# Out:
# india           1
# usa             2
# soutth korea    3
# german          4
# dtype: int64

# %%
SER['india']
# Out:
# np.int64(1)

# %%
SER['usa']
# Out:
# np.int64(2)

# %% [markdown]
# **Operations on Series**

# %%
SER2=pd.Series([1,2,3,4],index=['india','uk','south korea','german'])

# %%
SER+SER2
# Out:
# german          8.0
# india           2.0
# south korea     NaN
# soutth korea    NaN
# uk              NaN
# usa             NaN
# dtype: float64

# %%
scores=pd.Series([65,78,90,95],index=["ALI","SARA","JOHN","Mina"])
scores
# Out:
# ALI     65
# SARA    78
# JOHN    90
# Mina    95
# dtype: int64

# %%
scores["JOHN"]
# Out:
# np.int64(90)

# %%
temps=pd.Series([12.5, 15.0, 20.3, 18.8, 25.1],index=["Mon", "Tue", "Wed", "Thu", "Fri"])
temps
# Out:
# Mon    12.5
# Tue    15.0
# Wed    20.3
# Thu    18.8
# Fri    25.1
# dtype: float64

# %%
temps.mean()
# Out:
# np.float64(18.339999999999996)

# %%
temps.max()
# Out:
# 25.1

# %%
temps.idxmax()
# Out:
# 'Fri'

# %%
sales=pd.Series([100, 150, 80, 200, 50, 300, 120],index=["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"])

# %%
newSales=sales[sales>=150]
newSales
# Out:
# Tue    150
# Thu    200
# Sat    300
# dtype: int64

# %%
total_high = newSales.sum()
total_high
# Out:
# np.int64(650)

# %% [markdown]
# **DataFrame**

# %%
data={"name":["khan","Ali"],
      "age": [20, 22],
    "score": [85, 90]}
df=pd.DataFrame(data)
df
# Out:
#    name  age  score
# 0  khan   20     85
# 1   Ali   22     90

# %%
students=pd.DataFrame({"Name":["Ali","Sara","John","Mina"],
                       "Ages":[20,21,19,22],
                       "Majors":["CS","Math","CS","Physics"]})
students
# Out:
#    Name  Ages   Majors
# 0   Ali    20       CS
# 1  Sara    21     Math
# 2  John    19       CS
# 3  Mina    22  Physics

# %%
students.shape
# Out:
# (4, 3)

# %%
products=pd.DataFrame({"product": ["A", "B", "C", "D"],
                       "price": [1000, 1500, 700, 1200],
                       "stock": [5, 0, 10, 3]})
products
# Out:
#   product  price  stock
# 0       A   1000      5
# 1       B   1500      0
# 2       C    700     10
# 3       D   1200      3

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   product  4 non-null      object
#  1   price    4 non-null      int64
#  2   stock    4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
products.describe()
# Out:
#              price      stock
# count     4.000000   4.000000
# mean   1100.000000   4.500000
# std     336.650165   4.203173
# min     700.000000   0.000000
# 25%     925.000000   2.250000
# 50%    1100.000000   4.000000
# 75%    1275.000000   6.250000
# max    1500.000000  10.000000

# %%
# For price, it is 1100.000000 and for stock: 4.500000

# %%
weather=pd.DataFrame({
    "city": ["Seoul", "Busan", "Incheon", "Daegu"],
    "temp": [22.5, 25.0, 21.0, 27.3],
    "humidity": [60, 70, 65, 55]
})

weather
# Out:
#       city  temp  humidity
# 0    Seoul  22.5        60
# 1    Busan  25.0        70
# 2  Incheon  21.0        65
# 3    Daegu  27.3        55

# %%
weather.head(2)
# Out:
#     city  temp  humidity
# 0  Seoul  22.5        60
# 1  Busan  25.0        70

# %%
weather.shape
# Out:
# (4, 3)

# %%
weather.describe().max()
# Out:
# temp        27.3
# humidity    70.0
# dtype: float64

# %%
weather.describe().mean()
# Out:
# temp        18.809586
# humidity    48.181872
# dtype: float64

# %%
data = {
    "name": ["Ali", "Sara", "John", "Mina"],
    "age": [20, 21, 19, 22],
    "score": [85, 92, 78, 88]
}

df = pd.DataFrame(data)

df
# Out:
#    name  age  score
# 0   Ali   20     85
# 1  Sara   21     92
# 2  John   19     78
# 3  Mina   22     88

# %%
df["age"]
# Out:
# 0    20
# 1    21
# 2    19
# 3    22
# Name: age, dtype: int64

# %%
name_score=df[["name","score"]]
name_score
# Out:
#    name  score
# 0   Ali     85
# 1  Sara     92
# 2  John     78
# 3  Mina     88

# %%
df2=df.set_index("name")
df2
# Out:
#       age  score
# name
# Ali    20     85
# Sara   21     92
# John   19     78
# Mina   22     88

# %%
df2.loc["Sara"]
# Out:
# age      21
# score    92
# Name: Sara, dtype: int64

# %%
df2.loc[["Sara","John"]]
# Out:
#       age  score
# name
# Sara   21     92
# John   19     78

# %%
df2.loc["Mina","score"]
# Out:
# np.int64(88)

# %%
df
# Out:
#    name  age  score
# 0   Ali   20     85
# 1  Sara   21     92
# 2  John   19     78
# 3  Mina   22     88

# %%
df.iloc[[0,1]]
# Out:
#    name  age  score
# 0   Ali   20     85
# 1  Sara   21     92

# %%
df.iloc[:2]
# Out:
#    name  age  score
# 0   Ali   20     85
# 1  Sara   21     92

# %%
df.iloc[-2:]
# Out:
#    name  age  score
# 2  John   19     78
# 3  Mina   22     88

# %%
df.iloc[2]
# Out:
# name     John
# age        19
# score      78
# Name: 2, dtype: object

# %%
newDT=df.loc[[1,2],["age","score"]]

# %%
newDT
# Out:
#    age  score
# 1   21     92
# 2   19     78

# %%
new_df = df.iloc[1:3, 1:3]
new_df
# Out:
#    age  score
# 1   21     92
# 2   19     78
